# %%
# simulating amm in with different fee amounts
from functools import total_ordering
import pandas as pd

# %%
# Load AAPL and MSFT data
aapl_data = pd.read_excel("aapl_10-25-2024_1_min.xlsx")
msft_data = pd.read_excel("msft_25-10-2024_1_min.xlsx")
aapl_data['Time'] = pd.to_datetime(aapl_data['Time'], format="%m/%d/%Y %I:%M:%S %p")
msft_data['Time'] = pd.to_datetime(msft_data['Time'], format="%m/%d/%Y %I:%M:%S %p")

print(aapl_data)
# Out:
#        Open    High     Low   Close  Volume                Time
# 0    227.75  227.95  227.46  227.56    3426 2024-10-25 00:00:00
# 1    227.50  228.24  227.34  227.89    5158 2024-10-25 00:01:00
# 2    227.80  228.02  227.53  227.86    5954 2024-10-25 00:02:00
# 3    227.87  227.88  227.88  227.89     877 2024-10-25 00:03:00
# 4    227.89  228.20  227.80  228.20    1003 2024-10-25 00:04:00
# ..      ...     ...     ...     ...     ...                 ...
# 897  230.90  230.90  230.82  230.85      46 2024-10-25 15:55:00
# 898  230.80  230.80  230.80  230.80     210 2024-10-25 15:56:00
# 899  230.85  230.85  230.85  230.85     202 2024-10-25 15:57:00
# 900  230.92  230.99  230.92  230.97      60 2024-10-25 15:58:00
# 901  231.00  231.00  231.00  231.00      44 2024-10-25 15:59:00
#
# [902 rows x 6 columns]

# %%
# Merge unique timestamps from both datasets and sort them
unique_times = pd.concat([aapl_data['Time'], msft_data['Time']]).drop_duplicates().sort_values()
print(unique_times)
# Out:
# 0     2024-10-25 00:00:00
# 1     2024-10-25 00:01:00
# 2     2024-10-25 00:02:00
# 3     2024-10-25 00:03:00
# 4     2024-10-25 00:04:00
#               ...
# 897   2024-10-25 15:55:00
# 898   2024-10-25 15:56:00
# 899   2024-10-25 15:57:00
# 900   2024-10-25 15:58:00
# 901   2024-10-25 15:59:00
# Name: Time, Length: 931, dtype: datetime64[ns]

# %%
# Define manual start and end indices (default 0 for full range)
manual_start_index = 10  # Set to desired index, e.g., 4
manual_end_index = len(unique_times) - 1  # Set to desired index, e.g., 10

# Validate and adjust the indices if out of range
if manual_start_index < 0 or manual_start_index >= len(unique_times):
    manual_start_index = 0
if manual_end_index < 0 or manual_end_index >= len(unique_times):
    manual_end_index = len(unique_times) - 1

# Get the corresponding times for the selected indices
period_start = unique_times.iloc[manual_start_index]
period_end = unique_times.iloc[manual_end_index]

# Filter unique times within the selected range
filtered_times = unique_times.iloc[manual_start_index:manual_end_index + 1]

# Print the selected period and filtered times for verification
print(f"Simulation Period: {period_start} to {period_end}")
print(filtered_times)
# Out:
# Simulation Period: 2024-10-25 00:10:00 to 2024-10-25 15:59:00
# 9     2024-10-25 00:10:00
# 10    2024-10-25 00:11:00
# 11    2024-10-25 00:12:00
# 11    2024-10-25 00:13:00
# 12    2024-10-25 00:14:00
#               ...
# 897   2024-10-25 15:55:00
# 898   2024-10-25 15:56:00
# 899   2024-10-25 15:57:00
# 900   2024-10-25 15:58:00
# 901   2024-10-25 15:59:00
# Name: Time, Length: 921, dtype: datetime64[ns]

# %%
# Define assets and initialize parameters
#assets = ["USD", "AAPL", "MSFT"]
#opening_spots =  [1, 227.75, 426.38]
data = {"AAPL": aapl_data, "MSFT": msft_data}
#spots = {"USD": opening_spots[0], "AAPL": opening_spots[1], "MSFT": opening_spots[2]}
#weights = {"USD": 0.4, "AAPL": 0.3, "MSFT": 0.3}
initial_pool = 250000
#balances = {asset: (initial_pool * weights[asset]) / spots[asset] for asset in assets}
starting_table = pd.DataFrame({
    "asset": ["USD", "AAPL", "MSFT"],
    "spot": [1, 227.75, 426.38],
    "weight": [0.4, 0.3, 0.3],
})

starting_table["value"] = initial_pool * starting_table["weight"]
starting_table["balance"] = starting_table["value"] / starting_table["spot"]

starting_table.set_index("asset", inplace=True)

starting_table
# Out:
#          spot  weight     value        balance
# asset
# USD      1.00     0.4  100000.0  100000.000000
# AAPL   227.75     0.3   75000.0     329.308452
# MSFT   426.38     0.3   75000.0     175.899432

# %%
# Fee values for different scenarios
#fee_values = [0.1, 0.25, 0.3, 0.4, 0.5, 0.75, 0.9, 1, 1.25, 1.5, 2, 2.5]
fee_values = [1, 2, 3]
order_sizes = [0.25, 1, 2.5]

base_asset = starting_table.index[0]
if True:
  print(f"Base asset: {base_asset}")

  for asset in starting_table.index:
    print(asset)
# Out:
# Base asset: USD
# USD
# AAPL
# MSFT

# %%
#Calculate invariant based on balances and weights.
def calculate_invariant(inv_table):
    #inv = 1
    #for asset in assets:
    #    inv *= balances[asset] ** weights[asset]
    #for asset in assets_table.items():
        #inv *= asset["balance"] ** asset["weight"]
    #return inv
    return (inv_table["balance"] ** inv_table["weight"]).prod()

# %%
def print_pool_standing(info_table):
    #pd.DataFrame(info_table)
    print(f"Assets: {info_table.index}")
    #print(f"Weights: {weights}")
    print(f"Balances: {info_table["balance"]}")
    print(f"Inv: {calculate_invariant(info_table)}")
    #print("Values: ")
    total_pool_value = 0
    #for asset in assets:
        #total_pool_value += balances[asset] * opens[asset]
        #print("Asset ", asset, " value: ", balances[asset] * opens[asset])
        #inv *= balances[asset] ** weights[asset])
    print(f"Total pool value: {info_table["value"].sum()}")

# %%
def pretty_print_table(df):
    formatted_df = df.copy()  # Create a copy to avoid modifying the original DataFrame
    for col in formatted_df.select_dtypes(include=['float', 'int']).columns:
        formatted_df[col] = formatted_df[col].apply(lambda x: f"{x:,.4f}")
    print(formatted_df)

# %%
results = []
result_tables = []
direction = {}
#sim_table = starting_table
for order_size in order_sizes:
    print(f"Order Size simulation: {order_size}")
    # Loop through each fee variation
    for fee_percentage in fee_values:
        print(f"Fee % simulation: {fee_percentage}")
        sim_table = starting_table.copy()
        trades = 0
        fees_earned = 0
        fee = fee_percentage / 100
        # Initialize balances and invariant
        #balances = {asset: (initial_pool * weights[asset]) / spots[asset] for asset in assets}


        trades_log = []
        end_of_period_values = []

        # Loop through each unique time period
        # Fetch data for each asset at the current time and update last close prices if needed
        open_prices = {}
        last_close_prices = {}
        #open_prices[asset] = spots["USD"]
        #last_close_prices[asset] = spots["USD"]
        times = 0
        missing_data_log = {}
        for time in filtered_times:
            '''times += 1
            if times > 2:
                break'''
            #if trades > 10:
                #rint("breaking")
                #break

            if False:
                print(time)
                print(sim_table)
            missing_data_assets = set()
            #
            for asset in sim_table.index:
                if asset == base_asset:
                    #open_prices[asset] = spots["USD"]
                    #last_close_prices[asset] = spots["USD"]
                    pass
                else:
                    direction[asset] = None
                    asset_data = data[asset]
                    row = asset_data[asset_data['Time'] == time]
                    if row.empty:
                        print(f"No data for asset {asset} at time {time}")
                        missing_data_assets.add(asset)  # Flag the asse
                        # Log the missing data for later analysis
                        if time not in missing_data_log:
                            missing_data_log[time] = []
                        missing_data_log[time].append(asset)
                        continue
                    else:
                        sim_table.at[asset, "spot"] = row['Close'].values[0]
                    '''if not row.empty:
                        sim_table.at[asset, "spot"] = row['Open'].values[0]
                        last_close_prices[asset] = row['Close'].values[0]
                    else:
                        open_prices[asset] = sim_table.at[asset, "spot"]'''
                        

            # Trading loop for each asset
            continue_trading = True
            while continue_trading:
                continue_trading = False

                for asset in sim_table.index:
                    if asset == base_asset or asset in missing_data_assets:  # Skip flagged assets for this time
                        continue

                    #print(asset)

                    # Fetch high and low prices for the asset
                    row = data[asset][data[asset]['Time'] == time]
                    if not row.empty:
                        high_price = row['High'].values[0]
                        low_price = row['Low'].values[0]

                        # Calculate bid and ask prices for the current asset
                        '''other_balances_product = 1
                        for other_asset in assets:
                            if other_asset != asset and other_asset != "USD":
                                #print("other asset: ", other_asset, " balance: ", balances[other_asset], " weight: ", weights[other_asset])
                                other_balances_product *= balances[other_asset] ** weights[other_asset]

                        inv = calculate_invariant(balances, weights)'''
                        #inv = calculate_invariant(sim_table)
                        balance = sim_table.at[asset, "balance"]
                        weight = sim_table.at[asset, "weight"]

                        moe_balance = sim_table.at[base_asset, "balance"]
                        moe_weight = sim_table.at[base_asset, "weight"]
                        
                        if False:
                            print(f"Balance: {balance}, weight: {weight}")
                            other_balances_product = inv / (balance ** weight)
                            print(f"Inv: {inv}, Other bal product: {other_balances_product}")
                        #print("other asset balances produt: ", other_balances_product)
                        #print("balance of the asset: ", balances[asset])
                        #print("invariant: ", balances[asset]**weights[asset] * other_balances_product)

                        #bid_amount_wo_fee = abs(((inv / ((balance + order_size) ** weight * other_balances_product)) ** (1 / sim_table.at["USD", "weight"]) - sim_table.at["USD", "balance"]))
                        #ask_amount_wo_fee = abs(((inv / ((balance - order_size) ** weight * other_balances_product)) ** (1 / sim_table.at["USD", "weight"]) - sim_table.at["USD", "balance"]))

                        #bid_amount_wo_fee = sim_table.at["USD", "balance"] - (((sim_table.at["USD", "balance"]**sim_table.at["USD", "weight"] * balance**weight) / ((balance + order_size)**weight)))**(1 / sim_table.at["USD", "weight"])
                        #ask_amount_wo_fee = -sim_table.at["USD", "balance"] + (((sim_table.at["USD", "balance"]**sim_table.at["USD", "weight"] * balance**weight) / ((balance - order_size)**weight)))**(1 / sim_table.at["USD", "weight"])
                        
                        bid_amount_wo_fee = moe_balance - (((moe_balance**moe_weight * balance**weight) / ((balance + order_size)**weight)))**(1 / moe_weight)
                        ask_amount_wo_fee = -moe_balance+ (((moe_balance**moe_weight * balance**weight) / ((balance - order_size)**weight)))**(1 / moe_weight)
                        
                        bid_amount = bid_amount_wo_fee * (1 - fee)
                        ask_amount = ask_amount_wo_fee * (1 + fee)

                        bid_price = bid_amount / order_size
                        ask_price = ask_amount / order_size

                        if False:
                            print(asset, " bid: ", bid_price)
                            print(asset, " ask: ", ask_price)

                        # Sell asset
                        if high_price >= ask_price and direction[asset] != "buy":
                            if balance >= order_size:
                                direction[asset] = "sell"
                                trades += 1
                                if True:
                                    print("Trade: ", trades)
                                    print_pool_standing(sim_table)
                                    #trades_log.append({'Time': time, 'Asset': asset, 'Action': 'Sell', 'Shares': 1, 'Price': ask_price})
                                    #print({'Time': time, 'Asset': asset, 'Action': 'Sell', 'Shares': 1, 'Price': ask_price})
                                    trade_printout = {'Time': time, 'Asset': asset, 'Action': 'Sell', 'Quantity': order_size, 'Amount': round(float(ask_amount), 4), 'Price': round(float(ask_amount_wo_fee), 4)}
                                    trades_log.append(trade_printout)
                                    print(trade_printout)

                                sim_table.at[base_asset, "balance"] += ask_amount
                                sim_table.at[asset, "balance"] -= order_size
                                fees_earned += ask_amount - ask_amount_wo_fee

                                #inv = calculate_invariant(sim_table)
                                if True:
                                    print(f"Fee earned: {round(ask_amount - ask_amount_wo_fee, 4)} (total: {round(fees_earned, 4)}), With fee: {round(ask_amount, 4)}, without fee {round(ask_amount_wo_fee, 4)}")
                                    print_pool_standing(sim_table)
                                    print()
                                continue_trading = True  # Check for more trades within the period
                                break

                        # Buy asset
                        elif low_price <= bid_price and direction[asset] != "sell":
                            if moe_balance >= bid_price:
                                direction[asset] = "buy"

                                if True:
                                    trades += 1
                                    print("Trade: ", trades)
                                    print_pool_standing(sim_table)
                                    trade_printout = {'Time': time, 'Asset': asset, 'Action': 'Buy', 'Quantity': order_size, 'Amount': round(float(bid_amount), 4), 'Price': round(float(bid_price), 4)}
                                    trades_log.append(trade_printout)
                                    print(trade_printout)
                                sim_table.at[base_asset, "balance"] -= bid_amount
                                sim_table.at[asset, "balance"] += order_size
                                fees_earned += bid_amount_wo_fee - bid_amount

                                #inv = calculate_invariant(balances, weights)
                                if True:
                                    print(f"Fee earned: {round(bid_amount_wo_fee - bid_amount, 4)} (total: {round(fees_earned, 4)}), With fee: {round(bid_amount, 4)}, without fee {round(bid_amount_wo_fee, 4)}")
                                    print_pool_standing(sim_table)
                                    print()
                                continue_trading = True  # Check for more trades within the period
                                break

            for asset in sim_table.index:
                if asset == base_asset:
                    pass
                else:
                    row = asset_data[asset_data['Time'] == time]
                    # sim_table.at[asset, "spot"] = row['Close'].values[0]

                    sim_table.at[asset, "value"] = sim_table.at[asset, "spot"] * sim_table.at[asset, "balance"]

            # Calculate end-of-period pool value
            '''pool_value = balances["USD"]
            il_formula_end_value = 1
            for asset in assets:
                if asset != "USD":
                    pool_value += balances[asset] * last_close_prices[asset]
                    il_formula_end_value *= (last_close_prices[asset] / )
            end_of_period_values.append(pool_value)'''
            end_of_period_values.append(sim_table["value"].sum())

        # Record the final pool value for the current fee
        final_pool_value = end_of_period_values[-1]
        results.append({'Order Size': order_size, 'Fee %': fee_percentage, 'Final_Pool_Value': final_pool_value, "Fees": fees_earned, "Trades": trades})
        result_tables.append(sim_table)

# Convert results to DataFrame for comparison
results_df = pd.DataFrame(results)
# Out:
# Order Size simulation: 0.25
# Fee % simulation: 1
# No data for asset MSFT at time 2024-10-25 00:07:00
# No data for asset AAPL at time 2024-10-25 00:10:00
# No data for asset AAPL at time 2024-10-25 00:12:00
# No data for asset MSFT at time 2024-10-25 00:13:00
# No data for asset AAPL at time 2024-10-25 00:15:00
# No data for asset MSFT at time 2024-10-25 00:21:00
# No data for asset MSFT at time 2024-10-25 00:24:00
# No data for asset MSFT at time 2024-10-25 00:27:00
# No data for asset MSFT at time 2024-10-25 00:31:00
# No data for asset MSFT at time 2024-10-25 00:33:00
# No data for asset MSFT at time 2024-10-25 00:35:00
# No data for asset MSFT at time 2024-10-25 00:36:00
# No data for asset AAPL at time 2024-10-25 00:39:00
# No data for asset MSFT at time 2024-10-25 00:41:00
# No data for asset MSFT at time 2024-10-25 00:42:00
# No data for asset AAPL at time 2024-10-25 00:43:00
# No data for asset MSFT at time 2024-10-25 00:47:00
# No data for asset MSFT at time 2024-10-25 00:48:00
# No data for asset MSFT at time 2024-10-25 00:49:00
# No data for asset MSFT at time 2024-10-25 00:50:00
# No data for asset MSFT at time 2024-10-25 00:51:00
# No data for asset AAPL at time 2024-10-25 00:57:00
# No data for asset AAPL at time 2024-10-25 01:01:00
# No data for asset AAPL at time 2024-10-25 01:02:00
# No data for asset MSFT at time 2024-10-25 01:04:00
# No data for asset AAPL at time 2024-10-25 01:08:00
# No data for asset MSFT at time 2024-10-25 01:13:00
# No data for asset MSFT at time 2024-10-25 01:16:00
# No data for asset MSFT at time 2024-10-25 01:21:00
# No data for asset AAPL at time 2024-10-25 01:27:00
# No data for asset AAPL at time 2024-10-25 01:29:00
# No data for asset MSFT at time 2024-10-25 01:34:00
# No data for asset MSFT at time 2024-10-25 01:40:00
# No data for asset AAPL at time 2024-10-25 01:43:00
# No data for asset AAPL at time 2024-10-25 01:44:00
# No data for asset MSFT at time 2024-10-25 01:46:00
# No data for asset MSFT at time 2024-10-25 01:47:00
# No data for asset AAPL at time 2024-10-25 01:49:00
# No data for asset MSFT at time 2024-10-25 01:51:00
# No data for asset MSFT at time 2024-10-25 01:52:00
# No data for asset AAPL at time 2024-10-25 01:53:00
# No data for asset MSFT at time 2024-10-25 01:54:00
# No data for asset MSFT at time 2024-10-25 01:56:00
# No data for asset MSFT at time 2024-10-25 01:58:00
# No data for asset MSFT at time 2024-10-25 02:00:00
# No data for asset MSFT at time 2024-10-25 02:03:00
# No data for asset MSFT at time 2024-10-25 02:06:00
# No data for asset AAPL at time 2024-10-25 02:07:00
# No data for asset MSFT at time 2024-10-25 02:08:00
# No data for asset MSFT at time 2024-10-25 02:11:00
# No data for asset MSFT at time 2024-10-25 02:12:00
# No data for asset MSFT at time 2024-10-25 02:13:00
# No data for asset MSFT at time 2024-10-25 02:14:00
# No data for asset MSFT at time 2024-10-25 02:15:00
# No data for asset MSFT at time 2024-10-25 02:17:00
# No data for asset MSFT at time 2024-10-25 02:19:00
# No data for asset MSFT at time 2024-10-25 02:21:00
# No data for asset MSFT at time 2024-10-25 02:23:00
# No data for asset AAPL at time 2024-10-25 02:26:00
# No data for asset AAPL at time 2024-10-25 02:28:00
# No data for asset MSFT at time 2024-10-25 02:32:00
# No data for asset MSFT at time 2024-10-25 02:35:00
# No data for asset MSFT at time 2024-10-25 02:37:00
# No data for asset MSFT at time 2024-10-25 02:39:00
# No data for asset MSFT at time 2024-10-25 02:40:00
# No data for asset AAPL at time 2024-10-25 02:42:00
# No data for asset MSFT at time 2024-10-25 02:44:00
# No data for asset MSFT at time 2024-10-25 02:46:00
# No data for asset AAPL at time 2024-10-25 02:48:00
# No data for asset MSFT at time 2024-10-25 02:49:00
# No data for asset MSFT at time 2024-10-25 02:50:00
# No data for asset MSFT at time 2024-10-25 02:54:00
# No data for asset AAPL at time 2024-10-25 02:55:00
# No data for asset MSFT at time 2024-10-25 03:05:00
# No data for asset AAPL at time 2024-10-25 03:08:00
# No data for asset MSFT at time 2024-10-25 03:12:00
# No data for asset AAPL at time 2024-10-25 03:13:00
# No data for asset MSFT at time 2024-10-25 03:22:00
# No data for asset MSFT at time 2024-10-25 03:23:00
# No data for asset MSFT at time 2024-10-25 03:24:00
# No data for asset MSFT at time 2024-10-25 03:25:00
# No data for asset AAPL at time 2024-10-25 03:27:00
# No data for asset AAPL at time 2024-10-25 03:28:00
# No data for asset AAPL at time 2024-10-25 03:32:00
# No data for asset MSFT at time 2024-10-25 03:33:00
# No data for asset MSFT at time 2024-10-25 03:37:00
# No data for asset MSFT at time 2024-10-25 03:40:00
# No data for asset MSFT at time 2024-10-25 03:43:00
# No data for asset MSFT at time 2024-10-25 03:44:00
# No data for asset MSFT at time 2024-10-25 03:49:00
# No data for asset MSFT at time 2024-10-25 03:51:00
# No data for asset AAPL at time 2024-10-25 03:57:00
# No data for asset MSFT at time 2024-10-25 03:59:00
# Trade:  1
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100000.000000
# AAPL       329.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.480136286466
# Total pool value: 250327.3647924845
# {'Time': Timestamp('2024-10-25 04:00:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.5451, 'Price': 56.9753}
# Fee earned: 0.5698 (total: 0.5698), With fee: 57.5451, without fee 56.9753
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100057.545102
# AAPL       329.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.4862507598996
# Total pool value: 250327.3647924845
#
# Trade:  2
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100057.545102
# AAPL       329.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.4862507598996
# Total pool value: 250327.3647924845
# {'Time': Timestamp('2024-10-25 04:00:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.622, 'Price': 57.0515}
# Fee earned: 0.5705 (total: 1.1403), With fee: 57.622, without fee 57.0515
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100115.167092
# AAPL       328.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.492369893135
# Total pool value: 250327.3647924845
#
# Trade:  3
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100115.167092
# AAPL       328.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.492369893135
# Total pool value: 250904.75892480588
# {'Time': Timestamp('2024-10-25 05:33:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.699, 'Price': 57.1278}
# Fee earned: 0.5713 (total: 1.7115), With fee: 57.699, without fee 57.1278
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100172.866131
# AAPL       328.558452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.4984936932697
# Total pool value: 250904.75892480588
#
# Trade:  4
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100172.866131
# AAPL       328.558452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.4984936932697
# Total pool value: 250904.75892480588
# {'Time': Timestamp('2024-10-25 05:33:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.7763, 'Price': 57.2042}
# Fee earned: 0.572 (total: 2.2836), With fee: 57.7763, without fee 57.2042
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100230.642382
# AAPL       328.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.504622167417
# Total pool value: 250904.75892480588
#
# Trade:  5
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100230.642382
# AAPL       328.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.504622167417
# Total pool value: 251285.3216223517
# {'Time': Timestamp('2024-10-25 05:41:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8536, 'Price': 57.2808}
# Fee earned: 0.5728 (total: 2.8564), With fee: 57.8536, without fee 57.2808
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100288.496006
# AAPL       328.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.510755322707
# Total pool value: 251285.3216223517
#
# Trade:  6
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100288.496006
# AAPL       328.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.510755322707
# Total pool value: 251888.2544866903
# {'Time': Timestamp('2024-10-25 05:51:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.9312, 'Price': 57.3576}
# Fee earned: 0.5736 (total: 3.43), With fee: 57.9312, without fee 57.3576
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100346.427166
# AAPL       327.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5168931662856
# Total pool value: 251888.2544866903
#
# Trade:  7
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100346.427166
# AAPL       327.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5168931662856
# Total pool value: 252037.6058856889
# {'Time': Timestamp('2024-10-25 05:59:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 58.0089, 'Price': 57.4345}
# Fee earned: 0.5743 (total: 4.0043), With fee: 58.0089, without fee 57.4345
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100404.436026
# AAPL       327.558452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5230357053147
# Total pool value: 252037.6058856889
#
# Trade:  8
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100404.436026
# AAPL       327.558452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5230357053147
# Total pool value: 252023.79088005633
# {'Time': Timestamp('2024-10-25 06:03:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 58.0867, 'Price': 57.5116}
# Fee earned: 0.5751 (total: 4.5794), With fee: 58.0867, without fee 57.5116
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100462.522748
# AAPL       327.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5291829469734
# Total pool value: 252023.79088005633
#
# Trade:  9
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100462.522748
# AAPL       327.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5291829469734
# Total pool value: 251904.57771000115
# {'Time': Timestamp('2024-10-25 06:35:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 58.1647, 'Price': 57.5889}
# Fee earned: 0.5759 (total: 5.1553), With fee: 58.1647, without fee 57.5889
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100520.687498
# AAPL       327.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5353348984568
# Total pool value: 251904.57771000115
#
# Trade:  10
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100520.687498
# AAPL       327.058452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.5353348984568
# Total pool value: 251922.79274530598
# {'Time': Timestamp('2024-10-25 07:00:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 58.2429, 'Price': 57.6663}
# Fee earned: 0.5767 (total: 5.732), With fee: 58.2429, without fee 57.6663
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100578.930439
# AAPL       326.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.541491566976
# Total pool value: 251922.79274530598
#
# Trade:  11
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100578.930439
# AAPL       326.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.541491566976
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 106.0082, 'Price': 424.0327}
# Fee earned: 1.0708 (total: 6.8028), With fee: 106.0082, without fee 107.079
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100472.922274
# AAPL       326.808452
# MSFT       176.149432
# Name: balance, dtype: float64
# Inv: 2684.552935846063
# Total pool value: 250897.35982617096
#
# Trade:  12
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100472.922274
# AAPL       326.808452
# MSFT       176.149432
# Name: balance, dtype: float64
# Inv: 2684.552935846063
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 105.7463, 'Price': 422.9853}
# Fee earned: 1.0681 (total: 7.8709), With fee: 105.7463, without fee 106.8145
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100367.175947
# AAPL       326.808452
# MSFT       176.399432
# Name: balance, dtype: float64
# Inv: 2684.5643639345094
# Total pool value: 250897.35982617096
#
# Trade:  13
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100367.175947
# AAPL       326.808452
# MSFT       176.399432
# Name: balance, dtype: float64
# Inv: 2684.5643639345094
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 105.4855, 'Price': 421.942}
# Fee earned: 1.0655 (total: 8.9364), With fee: 105.4855, without fee 106.551
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100261.690441
# AAPL       326.808452
# MSFT       176.649432
# Name: balance, dtype: float64
# Inv: 2684.575775878132
# Total pool value: 250897.35982617096
#
# Trade:  14
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100261.690441
# AAPL       326.808452
# MSFT       176.649432
# Name: balance, dtype: float64
# Inv: 2684.575775878132
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 105.2257, 'Price': 420.9028}
# Fee earned: 1.0629 (total: 9.9993), With fee: 105.2257, without fee 106.2886
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100156.464744
# AAPL       326.808452
# MSFT       176.899432
# Name: balance, dtype: float64
# Inv: 2684.587171722551
# Total pool value: 250897.35982617096
#
# Trade:  15
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100156.464744
# AAPL       326.808452
# MSFT       176.899432
# Name: balance, dtype: float64
# Inv: 2684.587171722551
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.9669, 'Price': 419.8676}
# Fee earned: 1.0603 (total: 11.0596), With fee: 104.9669, without fee 106.0272
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100051.497852
# AAPL       326.808452
# MSFT       177.149432
# Name: balance, dtype: float64
# Inv: 2684.5985515131933
# Total pool value: 250897.35982617096
#
# Trade:  16
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100051.497852
# AAPL       326.808452
# MSFT       177.149432
# Name: balance, dtype: float64
# Inv: 2684.5985515131933
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.7091, 'Price': 418.8364}
# Fee earned: 1.0577 (total: 12.1173), With fee: 104.7091, without fee 105.7668
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99946.788764
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.6099152952947
# Total pool value: 250897.35982617096
#
# Trade:  17
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99946.788764
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.6099152952947
# Total pool value: 250897.35982617096
# {'Time': Timestamp('2024-10-25 13:12:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.4523, 'Price': 417.8091}
# Fee earned: 1.0551 (total: 13.1723), With fee: 104.4523, without fee 105.5074
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99842.336485
# AAPL      326.808452
# MSFT      177.649432
# Name: balance, dtype: float64
# Inv: 2684.621263113899
# Total pool value: 250897.35982617096
#
# Trade:  18
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99842.336485
# AAPL      326.808452
# MSFT      177.649432
# Name: balance, dtype: float64
# Inv: 2684.621263113899
# Total pool value: 249737.15713674133
# {'Time': Timestamp('2024-10-25 13:13:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 106.5636, 'Price': 105.5085}
# Fee earned: 1.0551 (total: 14.2274), With fee: 106.5636, without fee 105.5085
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99948.900037
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.632599001301
# Total pool value: 249737.15713674133
#
# Trade:  19
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99948.900037
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.632599001301
# Total pool value: 249737.15713674133
# {'Time': Timestamp('2024-10-25 13:13:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 106.8278, 'Price': 105.7701}
# Fee earned: 1.0577 (total: 15.2851), With fee: 106.8278, without fee 105.7701
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100055.727848
# AAPL       326.808452
# MSFT       177.149432
# Name: balance, dtype: float64
# Inv: 2684.643950914492
# Total pool value: 249737.15713674133
#
# Trade:  20
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100055.727848
# AAPL       326.808452
# MSFT       177.149432
# Name: balance, dtype: float64
# Inv: 2684.643950914492
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.7135, 'Price': 418.8541}
# Fee earned: 1.0577 (total: 16.3428), With fee: 104.7135, without fee 105.7712
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99951.014333
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.6553148887674
# Total pool value: 251443.9957895519
#
# Trade:  21
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99951.014333
# AAPL      326.808452
# MSFT      177.399432
# Name: balance, dtype: float64
# Inv: 2684.6553148887674
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.4567, 'Price': 417.8268}
# Fee earned: 1.0551 (total: 17.3979), With fee: 104.4567, without fee 105.5118
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99846.557637
# AAPL      326.808452
# MSFT      177.649432
# Name: balance, dtype: float64
# Inv: 2684.6666628992757
# Total pool value: 251443.9957895519
#
# Trade:  22
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99846.557637
# AAPL      326.808452
# MSFT      177.649432
# Name: balance, dtype: float64
# Inv: 2684.6666628992757
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.2009, 'Price': 416.8035}
# Fee earned: 1.0525 (total: 18.4505), With fee: 104.2009, without fee 105.2534
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99742.356771
# AAPL      326.808452
# MSFT      177.899432
# Name: balance, dtype: float64
# Inv: 2684.677994990873
# Total pool value: 251443.9957895519
#
# Trade:  23
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99742.356771
# AAPL      326.808452
# MSFT      177.899432
# Name: balance, dtype: float64
# Inv: 2684.677994990873
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.946, 'Price': 415.7841}
# Fee earned: 1.05 (total: 19.5004), With fee: 103.946, without fee 104.996
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99638.410751
# AAPL      326.808452
# MSFT      178.149432
# Name: balance, dtype: float64
# Inv: 2684.6893112082244
# Total pool value: 251443.9957895519
#
# Trade:  24
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99638.410751
# AAPL      326.808452
# MSFT      178.149432
# Name: balance, dtype: float64
# Inv: 2684.6893112082244
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.7759, 'Price': 57.2039}
# Fee earned: 0.572 (total: 20.0725), With fee: 57.7759, without fee 57.2039
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99696.186683
# AAPL      326.558452
# MSFT      178.149432
# Name: balance, dtype: float64
# Inv: 2684.695472940275
# Total pool value: 251443.9957895519
#
# Trade:  25
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99696.186683
# AAPL      326.558452
# MSFT      178.149432
# Name: balance, dtype: float64
# Inv: 2684.695472940275
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.7523, 'Price': 415.0091}
# Fee earned: 1.048 (total: 21.1205), With fee: 103.7523, without fee 104.8003
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99592.434401
# AAPL      326.558452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.7067733537956
# Total pool value: 251443.9957895519
#
# Trade:  26
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99592.434401
# AAPL      326.558452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.7067733537956
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.7935, 'Price': 57.2213}
# Fee earned: 0.5722 (total: 21.6927), With fee: 57.7935, without fee 57.2213
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99650.227913
# AAPL      326.308452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.712939843573
# Total pool value: 251443.9957895519
#
# Trade:  27
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99650.227913
# AAPL      326.308452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.712939843573
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.5593, 'Price': 414.2372}
# Fee earned: 1.0461 (total: 22.7387), With fee: 103.5593, without fee 104.6054
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99546.668608
# AAPL      326.308452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.7242244975014
# Total pool value: 251443.9957895519
#
# Trade:  28
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99546.668608
# AAPL      326.308452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.7242244975014
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8112, 'Price': 57.2389}
# Fee earned: 0.5724 (total: 23.3111), With fee: 57.8112, without fee 57.2389
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99604.479850
# AAPL      326.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.73039575227
# Total pool value: 251443.9957895519
#
# Trade:  29
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99604.479850
# AAPL      326.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.73039575227
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.3671, 'Price': 413.4683}
# Fee earned: 1.0441 (total: 24.3552), With fee: 103.3671, without fee 104.4112
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99501.112764
# AAPL      326.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.74166469066
# Total pool value: 251443.9957895519
#
# Trade:  30
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99501.112764
# AAPL      326.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.74166469066
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8291, 'Price': 57.2566}
# Fee earned: 0.5726 (total: 24.9278), With fee: 57.8291, without fee 57.2566
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99558.941885
# AAPL      325.808452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.747840717703
# Total pool value: 251443.9957895519
#
# Trade:  31
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99558.941885
# AAPL      325.808452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.747840717703
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.1756, 'Price': 412.7025}
# Fee earned: 1.0422 (total: 25.97), With fee: 103.1756, without fee 104.2178
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99455.766263
# AAPL      325.808452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2684.759093984424
# Total pool value: 251443.9957895519
#
# Trade:  32
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99455.766263
# AAPL      325.808452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2684.759093984424
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.925, 'Price': 411.7002}
# Fee earned: 1.0396 (total: 27.0096), With fee: 102.925, without fee 103.9647
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99352.841220
# AAPL      325.808452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.770331597291
# Total pool value: 251443.9957895519
#
# Trade:  33
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99352.841220
# AAPL      325.808452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.770331597291
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.7873, 'Price': 57.2151}
# Fee earned: 0.5722 (total: 27.5818), With fee: 57.7873, without fee 57.2151
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99410.628504
# AAPL      325.558452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.7765124297784
# Total pool value: 251443.9957895519
#
# Trade:  34
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99410.628504
# AAPL      325.558452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.7765124297784
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.7351, 'Price': 410.9406}
# Fee earned: 1.0377 (total: 28.6195), With fee: 102.7351, without fee 103.7729
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99307.893363
# AAPL      325.558452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.787734458181
# Total pool value: 251443.9957895519
#
# Trade:  35
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99307.893363
# AAPL      325.558452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.787734458181
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8055, 'Price': 57.2332}
# Fee earned: 0.5723 (total: 29.1918), With fee: 57.8055, without fee 57.2332
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99365.698890
# AAPL      325.308452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.793920077543
# Total pool value: 251443.9957895519
#
# Trade:  36
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99365.698890
# AAPL      325.308452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.793920077543
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.546, 'Price': 410.1839}
# Fee earned: 1.0358 (total: 30.2277), With fee: 102.546, without fee 103.5818
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99263.152909
# AAPL      325.308452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2684.805126564803
# Total pool value: 251443.9957895519
#
# Trade:  37
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99263.152909
# AAPL      325.308452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2684.805126564803
# Total pool value: 251443.9957895519
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8239, 'Price': 57.2514}
# Fee earned: 0.5725 (total: 30.8002), With fee: 57.8239, without fee 57.2514
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99320.976826
# AAPL      325.058452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2684.811316978372
# Total pool value: 251443.9957895519
#
# Trade:  38
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99320.976826
# AAPL      325.058452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2684.811316978372
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 104.6797, 'Price': 103.6432}
# Fee earned: 1.0364 (total: 31.8366), With fee: 104.6797, without fee 103.6432
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99425.656478
# AAPL      325.058452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.8225118562286
# Total pool value: 252214.66417561233
#
# Trade:  39
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99425.656478
# AAPL      325.058452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2684.8225118562286
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 104.936, 'Price': 103.897}
# Fee earned: 1.039 (total: 32.8756), With fee: 104.936, without fee 103.897
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99530.592461
# AAPL      325.058452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.8337223622757
# Total pool value: 252214.66417561233
#
# Trade:  40
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99530.592461
# AAPL      325.058452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2684.8337223622757
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 105.1933, 'Price': 104.1518}
# Fee earned: 1.0415 (total: 33.9171), With fee: 105.1933, without fee 104.1518
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99635.785761
# AAPL      325.058452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2684.844948540144
# Total pool value: 252214.66417561233
#
# Trade:  41
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99635.785761
# AAPL      325.058452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2684.844948540144
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 105.4516, 'Price': 104.4075}
# Fee earned: 1.0441 (total: 34.9612), With fee: 105.4516, without fee 104.4075
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99741.237369
# AAPL      325.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.856190433645
# Total pool value: 252214.66417561233
#
# Trade:  42
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99741.237369
# AAPL      325.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.856190433645
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 105.7109, 'Price': 104.6643}
# Fee earned: 1.0466 (total: 36.0078), With fee: 105.7109, without fee 104.6643
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99846.948283
# AAPL      325.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.8674480867767
# Total pool value: 252214.66417561233
#
# Trade:  43
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99846.948283
# AAPL      325.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.8674480867767
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 105.9712, 'Price': 104.922}
# Fee earned: 1.0492 (total: 37.057), With fee: 105.9712, without fee 104.922
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99952.919503
# AAPL      325.058452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.8787215437187
# Total pool value: 252214.66417561233
#
# Trade:  44
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99952.919503
# AAPL      325.058452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.8787215437187
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 106.2325, 'Price': 105.1807}
# Fee earned: 1.0518 (total: 38.1088), With fee: 106.2325, without fee 105.1807
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100059.152038
# AAPL       325.058452
# MSFT       178.149432
# Name: balance, dtype: float64
# Inv: 2684.8900108488397
# Total pool value: 252214.66417561233
#
# Trade:  45
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100059.152038
# AAPL       325.058452
# MSFT       178.149432
# Name: balance, dtype: float64
# Inv: 2684.8900108488397
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 106.4949, 'Price': 105.4405}
# Fee earned: 1.0544 (total: 39.1633), With fee: 106.4949, without fee 105.4405
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100165.646899
# AAPL       325.058452
# MSFT       177.899432
# Name: balance, dtype: float64
# Inv: 2684.9013160466943
# Total pool value: 252214.66417561233
#
# Trade:  46
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100165.646899
# AAPL       325.058452
# MSFT       177.899432
# Name: balance, dtype: float64
# Inv: 2684.9013160466943
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 106.7582, 'Price': 105.7012}
# Fee earned: 1.057 (total: 40.2203), With fee: 106.7582, without fee 105.7012
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100272.405104
# AAPL       325.058452
# MSFT       177.649432
# Name: balance, dtype: float64
# Inv: 2684.912637182024
# Total pool value: 252214.66417561233
#
# Trade:  47
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100272.405104
# AAPL       325.058452
# MSFT       177.649432
# Name: balance, dtype: float64
# Inv: 2684.912637182024
# Total pool value: 252214.66417561233
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 107.0226, 'Price': 105.9629}
# Fee earned: 1.0596 (total: 41.2799), With fee: 107.0226, without fee 105.9629
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100379.427677
# AAPL       325.058452
# MSFT       177.399432
# Name: balance, dtype: float64
# Inv: 2684.9239742997606
# Total pool value: 252214.66417561233
#
# Trade:  48
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100379.427677
# AAPL       325.058452
# MSFT       177.399432
# Name: balance, dtype: float64
# Inv: 2684.9239742997606
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.9044, 'Price': 419.6177}
# Fee earned: 1.0596 (total: 42.3395), With fee: 104.9044, without fee 105.9641
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100274.523256
# AAPL       325.058452
# MSFT       177.649432
# Name: balance, dtype: float64
# Inv: 2684.9353234458895
# Total pool value: 251114.46410665754
#
# Trade:  49
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100274.523256
# AAPL       325.058452
# MSFT       177.649432
# Name: balance, dtype: float64
# Inv: 2684.9353234458895
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.6475, 'Price': 418.59}
# Fee earned: 1.057 (total: 43.3966), With fee: 104.6475, without fee 105.7045
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100169.875761
# AAPL       325.058452
# MSFT       177.899432
# Name: balance, dtype: float64
# Inv: 2684.946656671514
# Total pool value: 251114.46410665754
#
# Trade:  50
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100169.875761
# AAPL       325.058452
# MSFT       177.899432
# Name: balance, dtype: float64
# Inv: 2684.946656671514
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.3916, 'Price': 417.5662}
# Fee earned: 1.0545 (total: 44.451), With fee: 104.3916, without fee 105.446
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100065.484203
# AAPL       325.058452
# MSFT       178.149432
# Name: balance, dtype: float64
# Inv: 2684.9579740213044
# Total pool value: 251114.46410665754
#
# Trade:  51
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100065.484203
# AAPL       325.058452
# MSFT       178.149432
# Name: balance, dtype: float64
# Inv: 2684.9579740213044
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 104.1366, 'Price': 416.5464}
# Fee earned: 1.0519 (total: 45.5029), With fee: 104.1366, without fee 105.1885
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99961.347599
# AAPL      325.058452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.969275539743
# Total pool value: 251114.46410665754
#
# Trade:  52
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99961.347599
# AAPL      325.058452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.969275539743
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.8826, 'Price': 415.5305}
# Fee earned: 1.0493 (total: 46.5522), With fee: 103.8826, without fee 104.9319
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99857.464969
# AAPL      325.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.9805612711275
# Total pool value: 251114.46410665754
#
# Trade:  53
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99857.464969
# AAPL      325.058452
# MSFT      178.649432
# Name: balance, dtype: float64
# Inv: 2684.9805612711275
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.6296, 'Price': 414.5185}
# Fee earned: 1.0468 (total: 47.599), With fee: 103.6296, without fee 104.6764
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99753.835341
# AAPL      325.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.9918312595664
# Total pool value: 251114.46410665754
#
# Trade:  54
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99753.835341
# AAPL      325.058452
# MSFT      178.899432
# Name: balance, dtype: float64
# Inv: 2684.9918312595664
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.3776, 'Price': 413.5104}
# Fee earned: 1.0442 (total: 48.6432), With fee: 103.3776, without fee 104.4218
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99650.457745
# AAPL      325.058452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2685.0030855489877
# Total pool value: 251114.46410665754
#
# Trade:  55
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99650.457745
# AAPL      325.058452
# MSFT      179.149432
# Name: balance, dtype: float64
# Inv: 2685.0030855489877
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 103.1265, 'Price': 412.5061}
# Fee earned: 1.0417 (total: 49.6849), With fee: 103.1265, without fee 104.1682
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99547.331219
# AAPL      325.058452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2685.014324183131
# Total pool value: 251114.46410665754
#
# Trade:  56
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99547.331219
# AAPL      325.058452
# MSFT      179.399432
# Name: balance, dtype: float64
# Inv: 2685.014324183131
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.8764, 'Price': 411.5057}
# Fee earned: 1.0392 (total: 50.7241), With fee: 102.8764, without fee 103.9156
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99444.454804
# AAPL      325.058452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2685.025547205557
# Total pool value: 251114.46410665754
#
# Trade:  57
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99444.454804
# AAPL      325.058452
# MSFT      179.649432
# Name: balance, dtype: float64
# Inv: 2685.025547205557
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.6273, 'Price': 410.509}
# Fee earned: 1.0366 (total: 51.7607), With fee: 102.6273, without fee 103.6639
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99341.827547
# AAPL      325.058452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2685.0367546596426
# Total pool value: 251114.46410665754
#
# Trade:  58
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99341.827547
# AAPL      325.058452
# MSFT      179.899432
# Name: balance, dtype: float64
# Inv: 2685.0367546596426
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.379, 'Price': 409.5162}
# Fee earned: 1.0341 (total: 52.7948), With fee: 102.379, without fee 103.4132
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99239.448499
# AAPL      325.058452
# MSFT      180.149432
# Name: balance, dtype: float64
# Inv: 2685.0479465885855
# Total pool value: 251114.46410665754
#
# Trade:  59
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99239.448499
# AAPL      325.058452
# MSFT      180.149432
# Name: balance, dtype: float64
# Inv: 2685.0479465885855
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 102.1318, 'Price': 408.5271}
# Fee earned: 1.0316 (total: 53.8265), With fee: 102.1318, without fee 103.1634
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99137.316717
# AAPL      325.058452
# MSFT      180.399432
# Name: balance, dtype: float64
# Inv: 2685.059123035402
# Total pool value: 251114.46410665754
#
# Trade:  60
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99137.316717
# AAPL      325.058452
# MSFT      180.399432
# Name: balance, dtype: float64
# Inv: 2685.059123035402
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.7951, 'Price': 57.2228}
# Fee earned: 0.5722 (total: 54.3987), With fee: 57.7951, without fee 57.2228
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99195.111776
# AAPL      324.808452
# MSFT      180.399432
# Name: balance, dtype: float64
# Inv: 2685.0653187965163
# Total pool value: 251114.46410665754
#
# Trade:  61
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99195.111776
# AAPL      324.808452
# MSFT      180.399432
# Name: balance, dtype: float64
# Inv: 2685.0653187965163
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 0.25, 'Amount': 101.9449, 'Price': 407.7794}
# Fee earned: 1.0297 (total: 55.4284), With fee: 101.9449, without fee 102.9746
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99093.166924
# AAPL      324.808452
# MSFT      180.649432
# Name: balance, dtype: float64
# Inv: 2685.0764798298005
# Total pool value: 251114.46410665754
#
# Trade:  62
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99093.166924
# AAPL      324.808452
# MSFT      180.649432
# Name: balance, dtype: float64
# Inv: 2685.0764798298005
# Total pool value: 251114.46410665754
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 0.25, 'Amount': 57.8138, 'Price': 57.2414}
# Fee earned: 0.5724 (total: 56.0009), With fee: 57.8138, without fee 57.2414
# ...
# {'Time': Timestamp('2024-10-25 13:20:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 2.5, 'Amount': 1069.8892, 'Price': 1059.2963}
# Fee earned: 10.593 (total: 48.097), With fee: 1069.8892, without fee 1059.2963
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100621.506036
# AAPL       326.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.9959861373763
# Total pool value: 251977.2641756123
#
# Trade:  6
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100621.506036
# AAPL       326.808452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.9959861373763
# Total pool value: 250877.00160665755
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 2.5, 'Amount': 1048.8137, 'Price': 419.5255}
# Fee earned: 10.5941 (total: 58.691), With fee: 1048.8137, without fee 1059.4078
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99572.692307
# AAPL      326.808452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2685.1102631549456
# Total pool value: 250877.00160665755
#
# Trade:  7
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99572.692307
# AAPL      326.808452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2685.1102631549456
# Total pool value: 250877.00160665755
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 2.5, 'Amount': 1023.5132, 'Price': 409.4053}
# Fee earned: 10.3385 (total: 69.0295), With fee: 1023.5132, without fee 1033.8517
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     98549.179111
# AAPL      326.808452
# MSFT      180.899432
# Name: balance, dtype: float64
# Inv: 2685.222946375363
# Total pool value: 250877.00160665755
#
# Trade:  8
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     98549.179111
# AAPL      326.808452
# MSFT      180.899432
# Name: balance, dtype: float64
# Inv: 2685.222946375363
# Total pool value: 250877.00160665755
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 2.5, 'Amount': 574.9102, 'Price': 569.2181}
# Fee earned: 5.6922 (total: 74.7217), With fee: 574.9102, without fee 569.2181
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99124.089354
# AAPL      324.308452
# MSFT      180.899432
# Name: balance, dtype: float64
# Inv: 2685.2846282068713
# Total pool value: 250877.00160665755
#
# Trade:  9
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99124.089354
# AAPL      324.308452
# MSFT      180.899432
# Name: balance, dtype: float64
# Inv: 2685.2846282068713
# Total pool value: 252476.8031312789
# {'Time': Timestamp('2024-10-25 13:22:00'), 'Asset': 'MSFT', 'Action': 'Sell', 'Quantity': 2.5, 'Amount': 1050.392, 'Price': 1039.992}
# Fee earned: 10.3999 (total: 85.1216), With fee: 1050.392, without fee 1039.992
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100174.481311
# AAPL       324.308452
# MSFT       178.399432
# Name: balance, dtype: float64
# Inv: 2685.396148728347
# Total pool value: 252476.8031312789
#
# No data for asset MSFT at time 2024-10-25 13:35:00
# No data for asset MSFT at time 2024-10-25 13:42:00
# No data for asset AAPL at time 2024-10-25 14:47:00
# No data for asset AAPL at time 2024-10-25 14:49:00
# No data for asset MSFT at time 2024-10-25 14:50:00
# No data for asset MSFT at time 2024-10-25 15:09:00
# No data for asset MSFT at time 2024-10-25 15:59:00
# Fee % simulation: 2
# No data for asset MSFT at time 2024-10-25 00:07:00
# No data for asset AAPL at time 2024-10-25 00:10:00
# No data for asset AAPL at time 2024-10-25 00:12:00
# No data for asset MSFT at time 2024-10-25 00:13:00
# No data for asset AAPL at time 2024-10-25 00:15:00
# No data for asset MSFT at time 2024-10-25 00:21:00
# No data for asset MSFT at time 2024-10-25 00:24:00
# No data for asset MSFT at time 2024-10-25 00:27:00
# No data for asset MSFT at time 2024-10-25 00:31:00
# No data for asset MSFT at time 2024-10-25 00:33:00
# No data for asset MSFT at time 2024-10-25 00:35:00
# No data for asset MSFT at time 2024-10-25 00:36:00
# No data for asset AAPL at time 2024-10-25 00:39:00
# No data for asset MSFT at time 2024-10-25 00:41:00
# No data for asset MSFT at time 2024-10-25 00:42:00
# No data for asset AAPL at time 2024-10-25 00:43:00
# No data for asset MSFT at time 2024-10-25 00:47:00
# No data for asset MSFT at time 2024-10-25 00:48:00
# No data for asset MSFT at time 2024-10-25 00:49:00
# No data for asset MSFT at time 2024-10-25 00:50:00
# No data for asset MSFT at time 2024-10-25 00:51:00
# No data for asset AAPL at time 2024-10-25 00:57:00
# No data for asset AAPL at time 2024-10-25 01:01:00
# No data for asset AAPL at time 2024-10-25 01:02:00
# No data for asset MSFT at time 2024-10-25 01:04:00
# No data for asset AAPL at time 2024-10-25 01:08:00
# No data for asset MSFT at time 2024-10-25 01:13:00
# No data for asset MSFT at time 2024-10-25 01:16:00
# No data for asset MSFT at time 2024-10-25 01:21:00
# No data for asset AAPL at time 2024-10-25 01:27:00
# No data for asset AAPL at time 2024-10-25 01:29:00
# No data for asset MSFT at time 2024-10-25 01:34:00
# No data for asset MSFT at time 2024-10-25 01:40:00
# No data for asset AAPL at time 2024-10-25 01:43:00
# No data for asset AAPL at time 2024-10-25 01:44:00
# No data for asset MSFT at time 2024-10-25 01:46:00
# No data for asset MSFT at time 2024-10-25 01:47:00
# No data for asset AAPL at time 2024-10-25 01:49:00
# No data for asset MSFT at time 2024-10-25 01:51:00
# No data for asset MSFT at time 2024-10-25 01:52:00
# No data for asset AAPL at time 2024-10-25 01:53:00
# No data for asset MSFT at time 2024-10-25 01:54:00
# No data for asset MSFT at time 2024-10-25 01:56:00
# No data for asset MSFT at time 2024-10-25 01:58:00
# No data for asset MSFT at time 2024-10-25 02:00:00
# No data for asset MSFT at time 2024-10-25 02:03:00
# No data for asset MSFT at time 2024-10-25 02:06:00
# No data for asset AAPL at time 2024-10-25 02:07:00
# No data for asset MSFT at time 2024-10-25 02:08:00
# No data for asset MSFT at time 2024-10-25 02:11:00
# No data for asset MSFT at time 2024-10-25 02:12:00
# No data for asset MSFT at time 2024-10-25 02:13:00
# No data for asset MSFT at time 2024-10-25 02:14:00
# No data for asset MSFT at time 2024-10-25 02:15:00
# No data for asset MSFT at time 2024-10-25 02:17:00
# No data for asset MSFT at time 2024-10-25 02:19:00
# No data for asset MSFT at time 2024-10-25 02:21:00
# No data for asset MSFT at time 2024-10-25 02:23:00
# No data for asset AAPL at time 2024-10-25 02:26:00
# No data for asset AAPL at time 2024-10-25 02:28:00
# No data for asset MSFT at time 2024-10-25 02:32:00
# No data for asset MSFT at time 2024-10-25 02:35:00
# No data for asset MSFT at time 2024-10-25 02:37:00
# No data for asset MSFT at time 2024-10-25 02:39:00
# No data for asset MSFT at time 2024-10-25 02:40:00
# No data for asset AAPL at time 2024-10-25 02:42:00
# No data for asset MSFT at time 2024-10-25 02:44:00
# No data for asset MSFT at time 2024-10-25 02:46:00
# No data for asset AAPL at time 2024-10-25 02:48:00
# No data for asset MSFT at time 2024-10-25 02:49:00
# No data for asset MSFT at time 2024-10-25 02:50:00
# No data for asset MSFT at time 2024-10-25 02:54:00
# No data for asset AAPL at time 2024-10-25 02:55:00
# No data for asset MSFT at time 2024-10-25 03:05:00
# No data for asset AAPL at time 2024-10-25 03:08:00
# No data for asset MSFT at time 2024-10-25 03:12:00
# No data for asset AAPL at time 2024-10-25 03:13:00
# No data for asset MSFT at time 2024-10-25 03:22:00
# No data for asset MSFT at time 2024-10-25 03:23:00
# No data for asset MSFT at time 2024-10-25 03:24:00
# No data for asset MSFT at time 2024-10-25 03:25:00
# No data for asset AAPL at time 2024-10-25 03:27:00
# No data for asset AAPL at time 2024-10-25 03:28:00
# No data for asset AAPL at time 2024-10-25 03:32:00
# No data for asset MSFT at time 2024-10-25 03:33:00
# No data for asset MSFT at time 2024-10-25 03:37:00
# No data for asset MSFT at time 2024-10-25 03:40:00
# No data for asset MSFT at time 2024-10-25 03:43:00
# No data for asset MSFT at time 2024-10-25 03:44:00
# No data for asset MSFT at time 2024-10-25 03:49:00
# No data for asset MSFT at time 2024-10-25 03:51:00
# No data for asset AAPL at time 2024-10-25 03:57:00
# No data for asset MSFT at time 2024-10-25 03:59:00
# Trade:  1
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100000.000000
# AAPL       329.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.480136286466
# Total pool value: 251486.77091455192
# {'Time': Timestamp('2024-10-25 13:19:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 2.5, 'Amount': 1031.8069, 'Price': 412.7228}
# Fee earned: 21.0573 (total: 21.0573), With fee: 1031.8069, without fee 1052.8642
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     98968.193091
# AAPL      329.308452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.7086391175885
# Total pool value: 251486.77091455192
#
# No data for asset MSFT at time 2024-10-25 13:35:00
# Trade:  2
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     98968.193091
# AAPL      329.308452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.7086391175885
# Total pool value: 252583.8331806752
# {'Time': Timestamp('2024-10-25 13:36:00'), 'Asset': 'AAPL', 'Action': 'Sell', 'Quantity': 2.5, 'Amount': 578.6149, 'Price': 567.2696}
# Fee earned: 11.3454 (total: 32.4027), With fee: 578.6149, without fee 567.2696
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     99546.808035
# AAPL      326.808452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.831039826042
# Total pool value: 252583.8331806752
#
# No data for asset MSFT at time 2024-10-25 13:42:00
# No data for asset AAPL at time 2024-10-25 14:47:00
# No data for asset AAPL at time 2024-10-25 14:49:00
# No data for asset MSFT at time 2024-10-25 14:50:00
# No data for asset MSFT at time 2024-10-25 15:09:00
# No data for asset MSFT at time 2024-10-25 15:59:00
# Fee % simulation: 3
# No data for asset MSFT at time 2024-10-25 00:07:00
# No data for asset AAPL at time 2024-10-25 00:10:00
# No data for asset AAPL at time 2024-10-25 00:12:00
# No data for asset MSFT at time 2024-10-25 00:13:00
# No data for asset AAPL at time 2024-10-25 00:15:00
# No data for asset MSFT at time 2024-10-25 00:21:00
# No data for asset MSFT at time 2024-10-25 00:24:00
# No data for asset MSFT at time 2024-10-25 00:27:00
# No data for asset MSFT at time 2024-10-25 00:31:00
# No data for asset MSFT at time 2024-10-25 00:33:00
# No data for asset MSFT at time 2024-10-25 00:35:00
# No data for asset MSFT at time 2024-10-25 00:36:00
# No data for asset AAPL at time 2024-10-25 00:39:00
# No data for asset MSFT at time 2024-10-25 00:41:00
# No data for asset MSFT at time 2024-10-25 00:42:00
# No data for asset AAPL at time 2024-10-25 00:43:00
# No data for asset MSFT at time 2024-10-25 00:47:00
# No data for asset MSFT at time 2024-10-25 00:48:00
# No data for asset MSFT at time 2024-10-25 00:49:00
# No data for asset MSFT at time 2024-10-25 00:50:00
# No data for asset MSFT at time 2024-10-25 00:51:00
# No data for asset AAPL at time 2024-10-25 00:57:00
# No data for asset AAPL at time 2024-10-25 01:01:00
# No data for asset AAPL at time 2024-10-25 01:02:00
# No data for asset MSFT at time 2024-10-25 01:04:00
# No data for asset AAPL at time 2024-10-25 01:08:00
# No data for asset MSFT at time 2024-10-25 01:13:00
# No data for asset MSFT at time 2024-10-25 01:16:00
# No data for asset MSFT at time 2024-10-25 01:21:00
# No data for asset AAPL at time 2024-10-25 01:27:00
# No data for asset AAPL at time 2024-10-25 01:29:00
# No data for asset MSFT at time 2024-10-25 01:34:00
# No data for asset MSFT at time 2024-10-25 01:40:00
# No data for asset AAPL at time 2024-10-25 01:43:00
# No data for asset AAPL at time 2024-10-25 01:44:00
# No data for asset MSFT at time 2024-10-25 01:46:00
# No data for asset MSFT at time 2024-10-25 01:47:00
# No data for asset AAPL at time 2024-10-25 01:49:00
# No data for asset MSFT at time 2024-10-25 01:51:00
# No data for asset MSFT at time 2024-10-25 01:52:00
# No data for asset AAPL at time 2024-10-25 01:53:00
# No data for asset MSFT at time 2024-10-25 01:54:00
# No data for asset MSFT at time 2024-10-25 01:56:00
# No data for asset MSFT at time 2024-10-25 01:58:00
# No data for asset MSFT at time 2024-10-25 02:00:00
# No data for asset MSFT at time 2024-10-25 02:03:00
# No data for asset MSFT at time 2024-10-25 02:06:00
# No data for asset AAPL at time 2024-10-25 02:07:00
# No data for asset MSFT at time 2024-10-25 02:08:00
# No data for asset MSFT at time 2024-10-25 02:11:00
# No data for asset MSFT at time 2024-10-25 02:12:00
# No data for asset MSFT at time 2024-10-25 02:13:00
# No data for asset MSFT at time 2024-10-25 02:14:00
# No data for asset MSFT at time 2024-10-25 02:15:00
# No data for asset MSFT at time 2024-10-25 02:17:00
# No data for asset MSFT at time 2024-10-25 02:19:00
# No data for asset MSFT at time 2024-10-25 02:21:00
# No data for asset MSFT at time 2024-10-25 02:23:00
# No data for asset AAPL at time 2024-10-25 02:26:00
# No data for asset AAPL at time 2024-10-25 02:28:00
# No data for asset MSFT at time 2024-10-25 02:32:00
# No data for asset MSFT at time 2024-10-25 02:35:00
# No data for asset MSFT at time 2024-10-25 02:37:00
# No data for asset MSFT at time 2024-10-25 02:39:00
# No data for asset MSFT at time 2024-10-25 02:40:00
# No data for asset AAPL at time 2024-10-25 02:42:00
# No data for asset MSFT at time 2024-10-25 02:44:00
# No data for asset MSFT at time 2024-10-25 02:46:00
# No data for asset AAPL at time 2024-10-25 02:48:00
# No data for asset MSFT at time 2024-10-25 02:49:00
# No data for asset MSFT at time 2024-10-25 02:50:00
# No data for asset MSFT at time 2024-10-25 02:54:00
# No data for asset AAPL at time 2024-10-25 02:55:00
# No data for asset MSFT at time 2024-10-25 03:05:00
# No data for asset AAPL at time 2024-10-25 03:08:00
# No data for asset MSFT at time 2024-10-25 03:12:00
# No data for asset AAPL at time 2024-10-25 03:13:00
# No data for asset MSFT at time 2024-10-25 03:22:00
# No data for asset MSFT at time 2024-10-25 03:23:00
# No data for asset MSFT at time 2024-10-25 03:24:00
# No data for asset MSFT at time 2024-10-25 03:25:00
# No data for asset AAPL at time 2024-10-25 03:27:00
# No data for asset AAPL at time 2024-10-25 03:28:00
# No data for asset AAPL at time 2024-10-25 03:32:00
# No data for asset MSFT at time 2024-10-25 03:33:00
# No data for asset MSFT at time 2024-10-25 03:37:00
# No data for asset MSFT at time 2024-10-25 03:40:00
# No data for asset MSFT at time 2024-10-25 03:43:00
# No data for asset MSFT at time 2024-10-25 03:44:00
# No data for asset MSFT at time 2024-10-25 03:49:00
# No data for asset MSFT at time 2024-10-25 03:51:00
# No data for asset AAPL at time 2024-10-25 03:57:00
# No data for asset MSFT at time 2024-10-25 03:59:00
# Trade:  1
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     100000.000000
# AAPL       329.308452
# MSFT       175.899432
# Name: balance, dtype: float64
# Inv: 2684.480136286466
# Total pool value: 251455.12660665755
# {'Time': Timestamp('2024-10-25 13:21:00'), 'Asset': 'MSFT', 'Action': 'Buy', 'Quantity': 2.5, 'Amount': 1021.2783, 'Price': 408.5113}
# Fee earned: 31.5859 (total: 31.5859), With fee: 1021.2783, without fee 1052.8642
# Assets: Index(['USD', 'AAPL', 'MSFT'], dtype='object', name='asset')
# Balances: asset
# USD     98978.721733
# AAPL      329.308452
# MSFT      178.399432
# Name: balance, dtype: float64
# Inv: 2684.8228795941473
# Total pool value: 251455.12660665755
#
# No data for asset MSFT at time 2024-10-25 13:35:00
# No data for asset MSFT at time 2024-10-25 13:42:00
# No data for asset AAPL at time 2024-10-25 14:47:00
# No data for asset AAPL at time 2024-10-25 14:49:00
# No data for asset MSFT at time 2024-10-25 14:50:00
# No data for asset MSFT at time 2024-10-25 15:09:00
# No data for asset MSFT at time 2024-10-25 15:59:00

# %%
print(f"Base asset: {base_asset}")

print("Starting table (V0):")
pretty_print_table(starting_table)
print("   Value:               ", f"{starting_table['value'].sum():,.4f}")
print()

#print(sim_table)

print("Hold table (VH):")
hold_table = starting_table.copy()
hold_table['spot'] = sim_table['spot']
hold_table['value'] = hold_table['spot'] * hold_table['balance']
pretty_print_table(hold_table)
print("   Value:               ", f"{hold_table['value'].sum():,.4f}")
print()

print("Summary: ")
#print(results_df)
pretty_print_table(results_df)

import json

if True:
  print()
  print()
  print("End tables:")
  table_index = 1
  for result, table in zip(results, result_tables):
      # Print the summary for the table
      print(f"    Table: {table_index}")
      table_index += 1
      print(json.dumps(result, indent=4))
      # Print the table
      pretty_print_table(table)
      print("   Value:               ", f"{table['value'].sum():,.4f}")
# Out:
# Base asset: USD
# Starting table (V0):
#            spot  weight         value       balance
# asset
# USD      1.0000  0.4000  100,000.0000  100,000.0000
# AAPL   227.7500  0.3000   75,000.0000      329.3085
# MSFT   426.3800  0.3000   75,000.0000      175.8994
#    Value:                250,000.0000
#
# Hold table (VH):
#            spot  weight         value       balance
# asset
# USD      1.0000  0.4000  100,000.0000  100,000.0000
# AAPL   231.0000  0.3000   76,070.2525      329.3085
# MSFT   427.4871  0.3000   75,194.7383      175.8994
#    Value:                251,264.9907
#
# Summary:
#   Order Size   Fee % Final_Pool_Value     Fees   Trades
# 0     0.2500  1.0000     250,915.8432  68.5331  74.0000
# 1     0.2500  2.0000     251,773.4649  48.8153  26.0000
# 2     0.2500  3.0000     251,906.2214  19.0466   6.0000
# 3     1.0000  1.0000     250,964.9649  70.1034  19.0000
# 4     1.0000  2.0000     251,657.9649  42.7305   6.0000
# 5     1.0000  3.0000     252,119.9649  25.3325   2.0000
# 6     2.5000  1.0000     251,178.7085  85.1216   9.0000
# 7     2.5000  2.0000     251,756.2085  32.4027   2.0000
# 8     2.5000  3.0000     252,333.7085  31.5859   1.0000
#
#
# End tables:
#     Table: 1
# {
#     "Order Size": 0.25,
#     "Fee %": 1,
#     "Final_Pool_Value": 250915.84315645794,
#     "Fees": 68.53311697134494,
#     "Trades": 74
# }
#            spot  weight         value       balance
# asset
# USD      1.0000  0.4000  100,000.0000  100,416.7391
# AAPL   231.0000  0.3000   74,973.0025      324.5585
# MSFT   427.4871  0.3000   75,942.8407      177.6494
#    Value:                250,915.8432
#     Table: 2
# {
#     "Order Size": 0.25,
#     "Fee %": 2,
#     "Final_Pool_Value": 251773.46493145794,
#     "Fees": 48.81534755787146,
#     "Trades": 26
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  99,544.5589
# AAPL   231.0000  0.3000   75,723.7525     327.8085
# MSFT   427.4871  0.3000   76,049.7125     177.8994
#    Value:                251,773.4649
#     Table: 3
# {
#     "Order Size": 0.25,
#     "Fee %": 3,
#     "Final_Pool_Value": 251906.22138145793,
#     "Fees": 19.04655794854338,
#     "Trades": 6
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  99,384.1613
# AAPL   231.0000  0.3000   76,070.2525     329.3085
# MSFT   427.4871  0.3000   75,835.9689     177.3994
#    Value:                251,906.2214
#     Table: 4
# {
#     "Order Size": 1,
#     "Fee %": 1,
#     "Final_Pool_Value": 250964.96493145794,
#     "Fees": 70.10343960736554,
#     "Trades": 19
# }
#            spot  weight         value       balance
# asset
# USD      1.0000  0.4000  100,000.0000  100,370.4868
# AAPL   231.0000  0.3000   74,915.2525      324.3085
# MSFT   427.4871  0.3000   76,049.7125      177.8994
#    Value:                250,964.9649
#     Table: 5
# {
#     "Order Size": 1,
#     "Fee %": 2,
#     "Final_Pool_Value": 251657.96493145794,
#     "Fees": 42.73052715358014,
#     "Trades": 6
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  99,652.4826
# AAPL   231.0000  0.3000   75,608.2525     327.3085
# MSFT   427.4871  0.3000   76,049.7125     177.8994
#    Value:                251,657.9649
#     Table: 6
# {
#     "Order Size": 1,
#     "Fee %": 3,
#     "Final_Pool_Value": 252119.96493145794,
#     "Fees": 25.33251585557008,
#     "Trades": 2
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  99,180.9153
# AAPL   231.0000  0.3000   76,070.2525     329.3085
# MSFT   427.4871  0.3000   76,049.7125     177.8994
#    Value:                252,119.9649
#     Table: 7
# {
#     "Order Size": 2.5,
#     "Fee %": 1,
#     "Final_Pool_Value": 251178.70848145793,
#     "Fees": 85.12164624467243,
#     "Trades": 9
# }
#            spot  weight         value       balance
# asset
# USD      1.0000  0.4000  100,000.0000  100,174.4813
# AAPL   231.0000  0.3000   74,915.2525      324.3085
# MSFT   427.4871  0.3000   76,263.4560      178.3994
#    Value:                251,178.7085
#     Table: 8
# {
#     "Order Size": 2.5,
#     "Fee %": 2,
#     "Final_Pool_Value": 251756.20848145793,
#     "Fees": 32.40267489077485,
#     "Trades": 2
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  99,546.8080
# AAPL   231.0000  0.3000   75,492.7525     326.8085
# MSFT   427.4871  0.3000   76,263.4560     178.3994
#    Value:                251,756.2085
#     Table: 9
# {
#     "Order Size": 2.5,
#     "Fee %": 3,
#     "Final_Pool_Value": 252333.70848145793,
#     "Fees": 31.585925773227927,
#     "Trades": 1
# }
#            spot  weight         value      balance
# asset
# USD      1.0000  0.4000  100,000.0000  98,978.7217
# AAPL   231.0000  0.3000   76,070.2525     329.3085
# MSFT   427.4871  0.3000   76,263.4560     178.3994
#    Value:                252,333.7085
